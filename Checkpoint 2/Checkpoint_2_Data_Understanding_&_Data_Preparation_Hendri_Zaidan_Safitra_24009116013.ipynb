# %% [markdown]
# # Import Library dan Eksplor Dataset #

# %%
import pandas as pd

file_path = '/content/UberDataset.csv'

df = pd.read_csv(file_path)
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# # Bussiness Understanding #

# %% [markdown]
# Database ini diambil dari https://www.kaggle.com/datasets/abdul0haadi/uber-ride-booking-dataset

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# Memanpilkan dan memeriksa struktur dari databaset diatas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# Menampilkan type data dari setiap kolom

# %%
df.dtypes
# Out:
# START_DATE     object
# END_DATE       object
# CATEGORY       object
# START          object
# STOP           object
# MILES         float64
# PURPOSE        object
# dtype: object

# %% [markdown]
# Menampilkan Jumlah baris danb kolom dalam dataset

# %%
df.shape
# Out:
# (1156, 7)

# %% [markdown]
# Menampilkan statistik deskriptif dari dataset.

# %%
df.describe()
# Out:
#               MILES
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %% [markdown]
# Menampilkan analisis korelasi dari databset

# %%
print(df.corr(numeric_only=True))
# Out:
#        MILES
# MILES    1.0

# %% [markdown]
# # Data Preparation #

# %% [markdown]
# Database ini diambil dari https://www.kaggle.com/datasets/abdul0haadi/uber-ride-booking-dataset

# %% [markdown]
# Melakukan pengecekan nilai yang hilang ( Missing Values ) pada dataset

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# START_DATE     0.000000
# END_DATE       0.086505
# CATEGORY       0.086505
# START          0.086505
# STOP           0.086505
# MILES          0.000000
# PURPOSE       43.512111
# dtype: float64

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom END_DATE

# %%
df[df['END_DATE'].isnull()]
# Out:
#      START_DATE END_DATE CATEGORY START STOP    MILES PURPOSE
# 1155     Totals      NaN      NaN   NaN  NaN  12204.7     NaN

# %%
df[df['CATEGORY'].isnull()]
# Out:
#      START_DATE END_DATE CATEGORY START STOP    MILES PURPOSE
# 1155     Totals      NaN      NaN   NaN  NaN  12204.7     NaN

# %%
df[df['START'].isnull()]
# Out:
#      START_DATE END_DATE CATEGORY START STOP    MILES PURPOSE
# 1155     Totals      NaN      NaN   NaN  NaN  12204.7     NaN

# %% [markdown]
# Kolom 'END_DATE', 'CATEGORY', 'START', dan 'STOP' punya jumlah data kosong yang sama pada nomor 1155. Ini bisa jadi masalah saat kita menganalisis data.

# %%
df[df['PURPOSE'].isnull()]
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# 85    02-09-2016 10:54  02-09-2016 11:07  Personal       Whitebridge
# 86    02-09-2016 11:43  02-09-2016 11:50  Personal        Northwoods
# 87    02-09-2016 13:36  02-09-2016 13:52  Personal        Tanglewood
# ...                ...               ...       ...               ...
# 1066  12/19/2016 14:37  12/19/2016 14:50  Business  Unknown Location
# 1069  12/19/2016 19:05  12/19/2016 19:17  Business         Islamabad
# 1071   12/20/2016 8:49   12/20/2016 9:24  Business  Unknown Location
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1155            Totals               NaN       NaN               NaN
#
#                      STOP    MILES PURPOSE
# 1             Fort Pierce      5.0     NaN
# 32    Lake Wellingborough      7.2     NaN
# ...

# %% [markdown]
# Mengatasi Missing Value
#
# Disini saya akan mengimputasi kolom Purpose dengan beberapa alasan:
#
# 1. Karena presentase data yang hilang mencapai kurang dari 70%
# 2. Menghapus semua missing value bisa kehilangan data maupun informasi yang signifikan.
# 3. Mengimputasi kolom Purpose dengan modus.

# %%
df['PURPOSE'].fillna(df['PURPOSE'].mode()[0], inplace=True)
# Out:
# <ipython-input-19-17bfcc70234a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PURPOSE'].fillna(df['PURPOSE'].mode()[0], inplace=True)

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# **Menghapus Missing Value**
#
# Disini saya akan menghapus Baris nomor 1155 dengan beberapa alasan:
#
# 1. Data tidak lengkap kebanyakan kolom yang kosong kecuali Purpose dan Miles, yang mengakibatkan data kurang relevan.
#
# 2. Sebagian besar data baris tersebut hilang lebih baik dihapus.

# %%
df = df.drop(index=1155)

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#             Null Ratio %
# START_DATE           0.0
# END_DATE             0.0
# CATEGORY             0.0
# START                0.0
# STOP                 0.0
# MILES                0.0
# PURPOSE              0.0

# %% [markdown]
# **Menampilkan Duplicated Values**

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
df[df.duplicated()]
# Out:
#           START_DATE         END_DATE  CATEGORY   START  STOP  MILES  PURPOSE
# 492  6/28/2016 23:34  6/28/2016 23:59  Business  Durham  Cary    9.9  Meeting

# %% [markdown]
# Terdapat adanya data duplikasi, solusinya yaitu dengan menghapus semua duplikasinya

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [START_DATE, END_DATE, CATEGORY, START, STOP, MILES, PURPOSE]
# Index: []

# %% [markdown]
# Otomatis data duplikasinya terhapus

# %% [markdown]
# **MENCARI OUTLIERS PADA DATASET**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom  Persentase Outliers
# MILES             6.672444

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %% [markdown]
# Diperlihatkan presentase yang tidak terlalu tinggi tetapi saya tetap imputasi karena "Miles" merupakan variabel penting untuk analisis. Metode imputasinya yaitu dengan menggunakan Winsorizing yang merupakan mempertahankan semua data tanpa membuang nilai ekstrem.

# %%
columns_to_impute = ["MILES"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Melakukan pengecekan ulang pada dataset setelah diimputasi

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom          Persentase Outliers
# MILES                          0.0
# TRIP_DURATION                  0.0

# %% [markdown]
# **Inconsistent Value**
#
# Memperbaiki format waktu dengan datatime karena memudahkan untuk menganalisis sebuah database

# %%
df["START_DATE"] = pd.to_datetime(df["START_DATE"], format="mixed")

# %%
df["END_DATE"] = pd.to_datetime(df["END_DATE"], format="mixed")

# %%
df
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# ...

# %% [markdown]
# **CONSTRUCT DATA**
#
# Disini saya menambahkan kolom yaitu waktu yang ditempuh dan kategori jaraknya karena untuk memudahkan menganalisis sebuah dataset

# %%
df["TRIP_DURATION"] = (pd.to_datetime(df["END_DATE"]) - pd.to_datetime(df["START_DATE"])).dt.total_seconds() / 60


df["DISTANCE_CATEGORY"] = df["MILES"].apply(lambda x: "Short" if x < 5 else "Medium" if x <= 20 else "Long")

print(df[["MILES", "TRIP_DURATION", "DISTANCE_CATEGORY"]].head())

# %%
df
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE  TRIP_DURATION  \
# ...

# %% [markdown]
# Mengecek kembali untuk outlinernya pada kolom TRIP_DURATION

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom          Persentase Outliers
# MILES                     0.000000
# TRIP_DURATION             5.372617

# %% [markdown]
# Diperlihatkan presentase yang tidak terlalu tinggi tetapi saya tetap imputasi karena "TRIP_DURATION" merupakan variabel penting untuk analisis. Metode imputasinya yaitu dengan menggunakan Winsorizing yang merupakan mempertahankan semua data tanpa membuang nilai ekstrem

# %%
columns_to_impute = ["TRIP_DURATION"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Winsorizing: Memotong outlier tanpa menghapus data
    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Melakukan pengecekan ulang pada dataset setelah diimputasi

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom          Persentase Outliers
# MILES                          0.0
# TRIP_DURATION                  0.0

# %% [markdown]
# **Dataset**
#
# Ini dataset yang sudah di Data Preparation.

# %%
df
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE  TRIP_DURATION  \
# ...
